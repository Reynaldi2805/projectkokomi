# %%
import pandas as pd
import numpy as np

# %%
genshin_data = 'Data Analisis Perkembangan Popularitas Kokomi (Responses).csv'
print(genshin_data)

df = pd.read_csv(genshin_data)
df.head
# Out:
# Data Analisis Perkembangan Popularitas Kokomi (Responses).csv
# <bound method NDFrame.head of               Timestamp Tulislah username anda di Genshin Impact  \
# 0   16/02/2023 10:35:40                                     `ivy
# 1   16/02/2023 10:36:42                                     Shin
# 2   16/02/2023 10:38:32                                      Mio
# 3   16/02/2023 10:40:27                                    Senra
# 4   16/02/2023 10:52:22                                   miyumy
# ..                  ...                                      ...
# 72  21/02/2023 22:01:46                                   Latte.
# 73  21/02/2023 22:24:15                                    FTR21
# 74  21/02/2023 22:48:16                                      wow
# 75  22/02/2023 02:42:48                                    Chiyo
# 76  23/02/2023 19:37:09                                     Tofu
#
#    Tulislah @ anda di twitter (Untuk di mention di Giveaway nya)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 22 columns):
#  #   Column                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                                                               77 non-null     object
#  1   Tulislah username anda di Genshin Impact                                                                                                                77 non-null     object
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Tulislah username anda di Genshin Impact',
#        'Tulislah @ anda di twitter (Untuk di mention di Giveaway nya)',
#        'Tulislah UID anda di Genshin Impact',
#        'Dari versi berapa anda bermain Genshin Impact',
#        'Akun anda berada di Adventure Rank (AR) berapa?',
#        'Apakah anda memiliki Kokomi di akun anda?',
#        'Sejak banner mana anda memiliki kokomi?',
#        'Apa alasan anda ingin pull kokomi dibandingkan karakter yang lain?',
#        'Apakah anda sempat melakukan top-up untuk mendapatkan kokomi? JIka iya silahkan pilih jumlah pengeluaran kalian untuk pull Kokomi',
#        'Apakah menurut kalian Kokomi merupakan karakter yang kurang fleksibel untuk digunakan di party tertentu?',
#        'Apakah Kokomi membantu anda dalam Eksplorasi?',
#        'Apakah anda menggunakan Kokomi dalam party Spiral Abyss?',
#        'Apa alasan anda tidak ingin pull kokomi?',
# ...

# %%
df['Apa alasan anda tidak ingin pull kokomi?'].value_counts()
# Out:
# Lebih menginginkan character lain selain Kokomi                                                                                                                                                                                                                                                                28
# Sudah pull tapi belum dapat, mungkin Hoyoverse lagu menguji kesabaran saya.                                                                                                                                                                                                                                     1
# Tidak memerlukan Kokomi                                                                                                                                                                                                                                                                                         1
# ...

# %%
df = df.loc[df['apa alasan'].str.contains('kalah rate off', case = false), 'apa alasan'] = 'Kalah Rate Off'
df['Apa alasan anda tidak ingin pull kokomi?'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = df.loc[df['apa alasan'].str.contains('kalah rate off', case = false), 'apa alasan'] = 'Kalah Rate Off'
#       2 df['Apa alasan anda tidak ingin pull kokomi?'].value_counts()
#
# AttributeError: 'str' object has no attribute 'loc'
