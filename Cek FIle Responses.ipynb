# %%
import pandas as pd
import numpy as np

# %%
genshin_data = 'Data Analisis Perkembangan Popularitas Kokomi (edited Responses).csv'
print(genshin_data)

df = pd.read_csv(genshin_data)
df.head
# Out:
# Data Analisis Perkembangan Popularitas Kokomi (edited Responses).csv
# <bound method NDFrame.head of               Timestamp Tulislah username anda di Genshin Impact  \
# 0   16/02/2023 10:35:40                                     `ivy
# 1   16/02/2023 10:36:42                                     Shin
# 2   16/02/2023 10:38:32                                      Mio
# 3   16/02/2023 10:40:27                                    Senra
# 4   16/02/2023 10:52:22                                   miyumy
# ..                  ...                                      ...
# 72  21/02/2023 22:01:46                                   Latte.
# 73  21/02/2023 22:24:15                                    FTR21
# 74  21/02/2023 22:48:16                                      wow
# 75  22/02/2023 02:42:48                                    Chiyo
# 76  23/02/2023 19:37:09                                     Tofu
#
#    Tulislah @ anda di twitter (Untuk di mention di Giveaway nya)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 22 columns):
#  #   Column                                                                                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                                                                                  --------------  -----
#  0   Timestamp                                                                                                                                               77 non-null     object
#  1   Tulislah username anda di Genshin Impact                                                                                                                77 non-null     object
# ...

# %%
df['Apa alasan anda tidak ingin pull kokomi?'].value_counts()
# Out:
# Lebih menginginkan character lain selain Kokomi                                               29
# Belum Main Pada Saat Kokomi Banner Rilis/Rerun                                                 7
# Kalah Rate Off                                                                                 6
# Menunggu Rerun                                                                                 4
# Tidak Ada Primogems                                                                            2
# Lebih menginginkan character lain selain Kokomi, Dan ke spook Qiqi👍🏻                           1
# Playstyle karakternya yang kurang menarik                                                      1
# Lebih menginginkan character lain selain Kokomi + Belum Main Pada Saat Kokomi Banner Rilis     1
# Belum Memahami Sistem Gacha Genshin                                                            1
# Lebih menginginkan character lain selain Kokomi, Kena spook 😔                                  1
# ...

# %%
dict_typo = {'Tidak memerlukan Kokomi' : 'Lebih menginginkan character lain selain Kokomi',
            'Kena spook 😔' : 'Kalah Rate Off' }
 
df_ganti = df.replace(dict_typo)
df_ganti['Apa alasan anda tidak ingin pull kokomi?'].value_counts()
# Out:
# Lebih menginginkan character lain selain Kokomi                                               30
# Belum Main Pada Saat Kokomi Banner Rilis/Rerun                                                 7
# Kalah Rate Off                                                                                 6
# Menunggu Rerun                                                                                 4
# Tidak Ada Primogems                                                                            2
# Lebih menginginkan character lain selain Kokomi, Dan ke spook Qiqi👍🏻                           1
# Playstyle karakternya yang kurang menarik                                                      1
# Lebih menginginkan character lain selain Kokomi + Belum Main Pada Saat Kokomi Banner Rilis     1
# Belum Memahami Sistem Gacha Genshin                                                            1
# Lebih menginginkan character lain selain Kokomi, Kena spook 😔                                  1
# ...

# %%
df['Apa alasan anda ingin pull kokomi dibandingkan karakter yang lain?'].value_counts()
# Out:
# Karakter nya yang menarik                                                                                                                                                                       6
# Butuh untuk komposisi party tertentu (Seperti Party Hyperbloom, Ayaka Freeze, dsb.)                                                                                                             4
# Karakter nya yang menarik, Perubahan/tambahan mekanis game yang menguntungkan untuk karakternya                                                                                                 3
# Karakter nya yang menarik, Perubahan/tambahan mekanis game yang menguntungkan untuk karakternya, Butuh untuk komposisi party tertentu (Seperti Party Hyperbloom, Ayaka Freeze, dsb.)            3
# Perubahan/tambahan mekanis game yang menguntungkan untuk karakternya, Butuh untuk komposisi party tertentu (Seperti Party Hyperbloom, Ayaka Freeze, dsb.)                                       2
# ...

# %%
df_ganti.head()
# Out:
#              Timestamp Tulislah username anda di Genshin Impact  \
# 0  16/02/2023 10:35:40                                     `ivy
# 1  16/02/2023 10:36:42                                     Shin
# 2  16/02/2023 10:38:32                                      Mio
# 3  16/02/2023 10:40:27                                    Senra
# 4  16/02/2023 10:52:22                                   miyumy
#
#   Tulislah @ anda di twitter (Untuk di mention di Giveaway nya)  \
# 0                                         @euthymiav
# 1                                          ngabartem
# 2                                      @keuthonimoss
# 3                                           @iunaqua
# 4                                          @yunaaemi
#
#   Tulislah UID anda di Genshin Impact  \
# 0                           818811043
# 1                           822284650
# 2                           822391828
# 3                           828228639
# 4                           861311908
#
# ...

# %%
df_ganti['Dari versi berapa anda bermain Genshin Impact'].value_counts()
# Out:
# Version 2.0 - 2.8     35
# Version 1.0 - 1.6     31
# Version 3.0 Keatas    11
# Name: Dari versi berapa anda bermain Genshin Impact, dtype: int64

# %%
df_ganti['Akun anda berada di Adventure Rank (AR) berapa?'].value_counts()
# Out:
# AR 55 – 60 (World Level 8)    67
# AR 40 – 45 (World Level 5)     5
# AR 45 – 50 (World Level 6)     4
# AR 30 – 35 (World Level 3)     1
# Name: Akun anda berada di Adventure Rank (AR) berapa?, dtype: int64

# %%
df_ganti['Apa alasan anda ingin pull kokomi dibandingkan karakter yang lain?'].value_counts()
# Out:
# Karakter nya yang menarik                                                                                                                                                                       6
# Butuh untuk komposisi party tertentu (Seperti Party Hyperbloom, Ayaka Freeze, dsb.)                                                                                                             4
# Karakter nya yang menarik, Perubahan/tambahan mekanis game yang menguntungkan untuk karakternya                                                                                                 3
# Karakter nya yang menarik, Perubahan/tambahan mekanis game yang menguntungkan untuk karakternya, Butuh untuk komposisi party tertentu (Seperti Party Hyperbloom, Ayaka Freeze, dsb.)            3
# Perubahan/tambahan mekanis game yang menguntungkan untuk karakternya, Butuh untuk komposisi party tertentu (Seperti Party Hyperbloom, Ayaka Freeze, dsb.)                                       2
# ...
